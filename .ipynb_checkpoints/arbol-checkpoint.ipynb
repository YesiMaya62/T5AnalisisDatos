# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

titanic_df = pd.read_csv("Titanic-Dataset.csv")

# %%
#  Análisis Exploratorio de Datos
print("\n-----2. Análisis Exploratorio -----")
print(titanic_df.head())  # Primeras filas del DataFrame
print(titanic_df.info())  # Información general (tipos de datos, valores no nulos)
print(titanic_df.describe())  # Estadísticas descriptivas (media, desviación estándar, etc.)

# Visualización de la Correlación entre variables numéricas
numeric_cols = titanic_df.select_dtypes(include=np.number).columns
correlation_matrix = titanic_df[numeric_cols].corr()
plt.figure(figsize=(10, 8)) #Aumentamos el tamaño de la figura
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Matriz de Correlación')
plt.show()


# Diagrama de dispersión para pares de variables numéricas
sns.pairplot(titanic_df[numeric_cols])
plt.show()

# Histograma de la variable objetivo ('Survived')
sns.histplot(titanic_df['Survived'])
plt.title('Distribución de la Variable Objetivo (Survived)')
plt.show()
# Out:
# -----2. Análisis Exploratorio -----
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# 3. Preprocesamiento de Datos

print("\n----- 3. Preprocesamiento de Datos -----")

# Define características numéricas y categóricas
numerical_features = ['Age', 'Fare', 'SibSp', 'Parch']
categorical_features = ['Sex', 'Embarked', 'Pclass']

# Pipeline de preprocesamiento
preprocessor = ColumnTransformer(
    transformers=[
        ('num', SimpleImputer(strategy='median'), numerical_features),
        ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features)
    ],
    remainder='drop'
)

# Crea un pipeline que combina preprocesamiento y el modelo de Árboles de Decisión
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', DecisionTreeClassifier(random_state=42))
])
# Out:
# ----- 3. Preprocesamiento de Datos -----

# %%
# 4. División del Conjunto de Datos (Train/Test)
print("\n----- 4. División del Conjunto de Datos -----")
X_train, X_test, y_train, y_test = train_test_split(titanic_df.drop('Survived', axis=1), titanic_df['Survived'], test_size=0.2, random_state=42)
# Out:
# ----- 4. División del Conjunto de Datos -----

# %%
# 5. Búsqueda de Hiperparámetros (usando GridSearchCV)
print("\n----- 5. Búsqueda de Hiperparámetros -----")
param_grid = {
    'classifier__max_depth': [None, 5, 10, 15],
    'classifier__min_samples_split': [2, 5, 10],
    'classifier__min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)

print("Mejores hiperparámetros:", grid_search.best_params_)
best_model = grid_search.best_estimator_
# Out:
# ----- 5. Búsqueda de Hiperparámetros -----
# Mejores hiperparámetros: {'classifier__max_depth': 5, 'classifier__min_samples_leaf': 2, 'classifier__min_samples_split': 10}

# %%
# 6. Entrenamiento del Modelo con los mejores hiperparámetros
print("\n----- 6. Entrenamiento del Modelo -----")
best_model.fit(X_train, y_train)
# Out:
# ----- 6. Entrenamiento del Modelo -----
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['Age', 'Fare', 'SibSp',
#                                                    'Parch']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Sex', 'Embarked',
#                                                    'Pclass'])])),
#                 ('classifier',
#                  DecisionTreeClassifier(max_depth=5, min_samples_leaf=2,
#                                         min_samples_split=10,
#                                         random_state=42))])

# %%
# 7. Evaluación del Modelo
print("\n----- 7. Evaluación del Modelo -----")

# Predicciones en los conjuntos de entrenamiento y prueba
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_test)


# Métricas de evaluación
print("Conjunto de Entrenamiento:")
print(classification_report(y_train, y_pred_train))
print(confusion_matrix(y_train, y_pred_train))

print("\nConjunto de Prueba:")
print(classification_report(y_test, y_pred_test))
print(confusion_matrix(y_test, y_pred_test))


# 7. Visualización de Resultados (Matriz de Confusión)
print("\n----- 7. Visualización de Resultados -----")
cm = confusion_matrix(y_test, y_pred_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['No sobrevivió', 'Sobrevivió'],
            yticklabels=['No sobrevivió', 'Sobrevivió'])
plt.xlabel('Predicciones')
plt.ylabel('Valores Reales')
plt.title('Matriz de Confusión')
plt.show()
# Out:
# ----- 7. Evaluación del Modelo -----
# Conjunto de Entrenamiento:
#               precision    recall  f1-score   support
#
#            0       0.82      0.96      0.89       444
#            1       0.91      0.66      0.76       268
#
#     accuracy                           0.85       712
#    macro avg       0.87      0.81      0.83       712
# weighted avg       0.86      0.85      0.84       712
#
# [[427  17]
#  [ 92 176]]
#
# Conjunto de Prueba:
#               precision    recall  f1-score   support
#
#            0       0.79      0.90      0.84       105
#            1       0.83      0.65      0.73        74
#
#     accuracy                           0.80       179
#    macro avg       0.81      0.78      0.78       179
# weighted avg       0.80      0.80      0.79       179
#
# [[95 10]
#  [26 48]]
#
# ----- 7. Visualización de Resultados -----

# %%
# 11. Gráfica del árbol de decisión (si es pequeño)
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 15)) #Aumenta el tamaño para mejor visibilidad
plot_tree(best_model['classifier'], filled=True, 
          feature_names=best_model['preprocessor'].get_feature_names_out(), 
          class_names=['No sobrevivió', 'Sobrevivió'], rounded=True)
plt.title('Árbol de Decisión')
plt.show()

# %%
# 8. Interpretación de Resultados (Similar a antes, pero con métricas de clasificación)
print("\n----- 8. Interpretación de Resultados -----")
print("El modelo de árbol de decisión, después de la búsqueda de hiperparámetros, muestra un rendimiento aceptable tanto en el conjunto de entrenamiento como en el de prueba.  Sin embargo, se observa un desequilibrio en el recall, indicando que el modelo es más preciso prediciendo la clase mayoritaria (no sobrevivientes).  Esto se puede mejorar mediante técnicas de manejo de desequilibrio de clases como sobremuestreo o submuestreo, o usando métricas de evaluación más adecuadas para datos desbalanceados como el AUC-ROC.")
print("La visualización del árbol proporciona una visión clara de las reglas de decisión utilizadas por el modelo para predecir la supervivencia. Se pueden observar las variables más importantes que influyen en la predicción y cómo se combinan para generar las decisiones.")
# Out:
# ----- 8. Interpretación de Resultados -----
# El modelo de árbol de decisión, después de la búsqueda de hiperparámetros, muestra un rendimiento aceptable tanto en el conjunto de entrenamiento como en el de prueba.  Sin embargo, se observa un desequilibrio en el recall, indicando que el modelo es más preciso prediciendo la clase mayoritaria (no sobrevivientes).  Esto se puede mejorar mediante técnicas de manejo de desequilibrio de clases como sobremuestreo o submuestreo, o usando métricas de evaluación más adecuadas para datos desbalanceados como el AUC-ROC.
# La visualización del árbol proporciona una visión clara de las reglas de decisión utilizadas por el modelo para predecir la supervivencia. Se pueden observar las variables más importantes que influyen en la predicción y cómo se combinan para generar las decisiones.
